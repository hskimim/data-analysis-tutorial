# %% [markdown]
# ### Chi-Square distribution
# - norm-dist를 따르는 rv 에서 나오는 sample들의 합을 정규화하면 norm dist를 따릅니다
# - norm-dist를 따르는 rv 에서 나오는 sample들의 합을 sample sigma로 정규화하면 t-dist를 따릅니다.
# - norm-dist를 따르는 rv 에서 나오는 sample들을 `sum of squre`하면!!!
# - Chi-Squre distribution을 따릅니다!!!
# - `Chi(ball shape of X)(x;nu)`
# - x_i ~ N(x)  sigma from i to n(x_i)^2 ~ Chi-square (x;n)

# %%
import matplotlib.pylab as plt
xx = np.linspace(0.01, 10, 100)
for df in [1, 2, 3, 4, 5, 6, 9]:
    rv = sp.stats.chi2(df=df)
    plt.plot(xx, rv.pdf(xx), label=("chi2 (dof = %d)" % df))
plt.xlim(0, 10.1)
plt.ylim(0, 0.6)
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# N이 커질 수록 정규화되는 것을 볼 수 있습니다. CLT를 보이는 것입니다.

# %% [markdown]
# ### F-distribution
# - t-dist와 chi-square-dist는 norm-dist를 따르는 하나의 rv 에서 나오는 sample data로부터 생성할 수 있었습니다.
# - 이와 달리 F-dist는 `독립적인 두 개의 rv`에서 나오는 sample data로부터 생성할 수 있습니다.
# - `(x_1/n_1) / (x_2/n_2) ~ F(n1,n2)`

# %%
xx = np.linspace(0.03, 3, 1000)
plt.plot(xx, sp.stats.f(1, 1).pdf(xx), label="F(1,1)")
plt.plot(xx, sp.stats.f(5, 1).pdf(xx), label="F(5,1)")
plt.plot(xx, sp.stats.f(10, 10).pdf(xx), label="F(10,10)")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# F 분보에서 특이한 점은 N1과 N2의 값이 같을 경우, 1 근처의 값이 가장 많이 발생할 것이라는 예상과는 달리 1이 아닌 어떤 수가 더 흔하게 발생한다는 점입니다.
